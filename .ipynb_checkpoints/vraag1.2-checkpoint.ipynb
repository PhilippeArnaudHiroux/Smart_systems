# %%
import pandas as pd
import numpy as np
from keras.layers import Input, Dense, LeakyReLU, BatchNormalization
from keras.models import Model, load_model
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import matplotlib 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("datasets/htx_weather.csv")
df=df.dropna(axis=0)
df.replace('Blank', 0, inplace=True)
df['RainTodayFlag']=df['rain_today'].apply(lambda x: 1 if x=='Yes' else 0)
df['RainTomorrowFlag']=df['rain_tomorrow'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
X=df[['min_temp', 'max_temp', 'rainfall', 'wind_speed9am', 'wind_speed3pm', 'humidity9am', 
      'humidity3pm', 'pressure9am', 'pressure3pm', 'temp9am', 'temp3pm', 'RainTodayFlag']]
y = df[['RainTomorrowFlag']]
scaler = MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=0)

# %%
n_inputs=X_train.shape[1]
n_bottleneck=(round(float(n_inputs)))

# %%
visible = Input(shape=(n_inputs,), name='Input-Layer')

# %%
e = Dense(units=n_inputs, name='Encoder-Layer')(visible)
e = BatchNormalization(name='Encoder-Layer-Normalization')(e)
e = LeakyReLU(name='Encoder-Layer-Activation')(e)

# %%
bottleneck = Dense(units=n_bottleneck, name='Bottleneck-Layer')(e)

# %%
d = Dense(units=n_inputs, name='Decoder-Layer')(bottleneck)
d = BatchNormalization(name='Decoder-Layer-Normalization')(d)
d = LeakyReLU(name='Decoder-Layer-Activation')(d)

# %%
output = Dense(units=n_inputs, activation='linear', name='Output-Layer')(d)

# %%
model = Model(inputs=visible, outputs=output, name='Autoencoder-Model')

# %%
model.compile(optimizer='adam', loss='mse')

# %%
print(model.summary())
# Out:
# Model: "Autoencoder-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input-Layer (InputLayer)    [(None, 12)]              0
#
#  Encoder-Layer (Dense)       (None, 12)                156
#
#  Encoder-Layer-Normalization  (None, 12)               48
#   (BatchNormalization)
#
#  Encoder-Layer-Activation (L  (None, 12)               0
#  eakyReLU)
#
#  Bottleneck-Layer (Dense)    (None, 12)                156
#
#  Decoder-Layer (Dense)       (None, 12)                156
#
#  Decoder-Layer-Normalization  (None, 12)               48
#   (BatchNormalization)
#
#  Decoder-Layer-Activation (L  (None, 12)               0
#  eakyReLU)
#
#  Output-Layer (Dense)        (None, 12)                156
#
# =================================================================
# Total params: 720
# Trainable params: 672
# Non-trainable params: 48
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, X_train, epochs=10, batch_size=16, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/10
# 183/183 [==============================] - 2s 8ms/step - loss: 0.3433 - val_loss: 0.1358
# Epoch 2/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0524 - val_loss: 0.0266
# Epoch 3/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0234 - val_loss: 0.0174
# Epoch 4/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0184 - val_loss: 0.0136
# Epoch 5/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0160 - val_loss: 0.0121
# Epoch 6/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0150 - val_loss: 0.0111
# Epoch 7/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0140 - val_loss: 0.0102
# Epoch 8/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0137 - val_loss: 0.0096
# Epoch 9/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0133 - val_loss: 0.0094
# Epoch 10/10
# 183/183 [==============================] - 1s 3ms/step - loss: 0.0124 - val_loss: 0.0091

# %%
fig, ax = plt.subplots(figsize=(16,9), dpi=300)
plt.title(label='Model Loss by Epoch', loc='center')

ax.plot(history.history['loss'], label='Training Data', color='black')
ax.plot(history.history['val_loss'], label='Test Data', color='red')
ax.set(xlabel='Epoch', ylabel='Loss')
plt.legend()

plt.show()

# %%
encoder = Model(inputs=visible, outputs=bottleneck)

# %%
encoder.compile(optimizer='adam', loss='mse')

# %%
encoder.save('encoder.h5')

# %%
encoder = load_model('encoder.h5')

# %%
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)
# Out:
# 92/92 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step

# %%
model = LogisticRegression(solver='sag')
clf = model.fit(X_train_encoded, y_train)
# Out:
# D:\Anaconda3\envs\SmartSystems\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Anaconda3\envs\SmartSystems\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
pred_labels_tr = model.predict(X_train_encoded)
pred_labels_te = model.predict(X_test_encoded)

# %%
print('Intercept (Beta 0): ', clf.intercept_)
print('Slope (Beta 1): ', clf.coef_)
# Out:
# Intercept (Beta 0):  [-0.97220063]
# Slope (Beta 1):  [[-0.36072773  0.15759459  0.44044644  0.08669261 -0.16792986 -0.3843609
#   -0.14794819 -1.0929801   0.20787638 -1.0756637  -0.22125082  0.22390611]]

# %%
score_te = model.score(X_test_encoded, y_test)
print('Accuracy score: ', score_te)
print(classification_report(y_test, pred_labels_te))
# Out:
# Accuracy score:  0.8071135430916553
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89       588
#            1       0.75      0.02      0.04       143
#
#     accuracy                           0.81       731
#    macro avg       0.78      0.51      0.47       731
# weighted avg       0.80      0.81      0.73       731

# %%
score_tr = model.score(X_train_encoded, y_train)
print('Accuracy score: ', score_tr)
print(classification_report(y_train, pred_labels_tr))
# Out:
# Accuracy score:  0.8181506849315069
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      2392
#            1       0.42      0.02      0.03       528
#
#     accuracy                           0.82      2920
#    macro avg       0.62      0.51      0.46      2920
# weighted avg       0.75      0.82      0.74      2920
